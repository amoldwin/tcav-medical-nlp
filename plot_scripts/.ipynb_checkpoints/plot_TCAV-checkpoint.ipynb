# %%
import json 
import os
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import math
import pickle
import seaborn as sns
from plot_utils import *

# %%
results_dir = '/data/moldwinar/torch_tcav/tcav_scripts/results'
cavs_dir = '/data/moldwinar/torch_tcav/tcav_scripts/'
nicu_experiment_names = ['logistic_best_steps_84.pt_500_pre_sum',
                         'NICU_MLP_0_checkpoint-28853_500_pool',
                         'CNN_NICU_best_steps_420.pt_500_dropout',
                         'FINALWeightedBlueBert512NicuLosAdmissions_2_checkpoint-26015_500_pool'
                         ]
nicu_concept_names =  ['Septicemia',
                        'Jaundice', 
                        'Other perinatal conditions',
                        'Suspected Infection', 
                        'Premature birth', 
                        'Patent ductus arteriosus',
                        'Needs Hepatitis Vaccination',
                        'Chronic respiratory disease',
                        'MALE', 'FEMALE', 
                        'Single Birth, Cesarean Section', 
                        'Low birth weight', 
                        'Sleep Apnea',                        
                        'Anemia of prematurity', 
                        'Retrolental fibroplasia', 
                        '3+ Birthmates, Cesarian Section', 
                        'Bradycardia', 
                        'Twin Birth, Cesarian Section',
                        'Respiratory Distress Syndrome',
#                        'Fake concept (not present)', 
                        'Sunday','Monday','Tuesday', 'Wednesday', 'Thursday','Friday','Saturday'
                        ]

# %%
NICU_targets = []
for i, exp in enumerate(nicu_experiment_names):
    targets=[exp+'_positive_'+x+'_.pk' for x in nicu_concept_names]
    results = plot_multiple(targets,codes=['positive_'+x for x in nicu_concept_names],scores_dir=os.path.join(results_dir,exp),
                        names=nicu_concept_names,normalized=True,metric='acc',
                        cav_dir=os.path.join(cavs_dir,exp) )
    NICU_targets.append(results)
# Out:
# file not found /data/moldwinar/torch_tcav/tcav_scripts/results/logistic_best_steps_84.pt_500_pre_sum/logistic_best_steps_84.pt_500_pre_sum_positive_Bradycardia_.pk
# file not found /data/moldwinar/torch_tcav/tcav_scripts/results/logistic_best_steps_84.pt_500_pre_sum/logistic_best_steps_84.pt_500_pre_sum_positive_Twin Birth, Cesarian Section_.pk
# file not found /data/moldwinar/torch_tcav/tcav_scripts/results/logistic_best_steps_84.pt_500_pre_sum/logistic_best_steps_84.pt_500_pre_sum_positive_Respiratory Distress Syndrome_.pk
# file not found /data/moldwinar/torch_tcav/tcav_scripts/results/logistic_best_steps_84.pt_500_pre_sum/logistic_best_steps_84.pt_500_pre_sum_positive_Fake concept (not present)_.pk
# file not found /data/moldwinar/torch_tcav/tcav_scripts/results/logistic_best_steps_84.pt_500_pre_sum/logistic_best_steps_84.pt_500_pre_sum_positive_Thursday_.pk
# file not found /data/moldwinar/torch_tcav/tcav_scripts/results/logistic_best_steps_84.pt_500_pre_sum/logistic_best_steps_84.pt_500_pre_sum_positive_Friday_.pk
# ['positive_Septicemia', 'positive_Jaundice', 'positive_Other perinatal conditions', 'positive_Suspected Infection', 'positive_Premature birth', 'positive_Patent ductus arteriosus', 'positive_Needs Hepatitis Vaccination', 'positive_Chronic respiratory disease', 'positive_MALE', 'positive_FEMALE', 'positive_Single Birth, Cesarean Section', 'positive_Low birth weight', 'positive_Sleep Apnea', 'positive_Anemia of prematurity', 'positive_Retrolental fibroplasia', 'positive_3+ Birthmates, Cesarian Section', 'positive_Bradycardia', 'positive_Twin Birth, Cesarian Section', 'positive_Respiratory Distress Syndrome', 'positive_Fake concept (not present)', 'positive_Sunday', 'positive_Monday', 'positive_Tuesday', 'positive_Wednesday', 'positive_Thursday', 'positive_Friday', 'positive_Saturday']
# file not found /data/moldwinar/torch_tcav/tcav_scripts/results/NICU_MLP_0_checkpoint-28853_500_pool/NICU_MLP_0_checkpoint-28853_500_pool_positive_Fake concept (not present)_.pk
# ['positive_Septicemia', 'positive_Jaundice', 'positive_Other perinatal conditions', 'positive_Suspected Infection', 'positive_Premature birth', 'positive_Patent ductus arteriosus', 'positive_Needs Hepatitis Vaccination', 'positive_Chronic respiratory disease', 'positive_MALE', 'positive_FEMALE', 'positive_Single Birth, Cesarean Section', 'positive_Low birth weight', 'positive_Sleep Apnea', 'positive_Anemia of prematurity', 'positive_Retrolental fibroplasia', 'positive_3+ Birthmates, Cesarian Section', 'positive_Bradycardia', 'positive_Twin Birth, Cesarian Section', 'positive_Respiratory Distress Syndrome', 'positive_Fake concept (not present)', 'positive_Sunday', 'positive_Monday', 'positive_Tuesday', 'positive_Wednesday', 'positive_Thursday', 'positive_Friday', 'positive_Saturday']
# file not found /data/moldwinar/torch_tcav/tcav_scripts/results/CNN_NICU_best_steps_420.pt_500_dropout/CNN_NICU_best_steps_420.pt_500_dropout_positive_Fake concept (not present)_.pk
# ['positive_Septicemia', 'positive_Jaundice', 'positive_Other perinatal conditions', 'positive_Suspected Infection', 'positive_Premature birth', 'positive_Patent ductus arteriosus', 'positive_Needs Hepatitis Vaccination', 'positive_Chronic respiratory disease', 'positive_MALE', 'positive_FEMALE', 'positive_Single Birth, Cesarean Section', 'positive_Low birth weight', 'positive_Sleep Apnea', 'positive_Anemia of prematurity', 'positive_Retrolental fibroplasia', 'positive_3+ Birthmates, Cesarian Section', 'positive_Bradycardia', 'positive_Twin Birth, Cesarian Section', 'positive_Respiratory Distress Syndrome', 'positive_Fake concept (not present)', 'positive_Sunday', 'positive_Monday', 'positive_Tuesday', 'positive_Wednesday', 'positive_Thursday', 'positive_Friday', 'positive_Saturday']
# file not found /data/moldwinar/torch_tcav/tcav_scripts/results/FINALWeightedBlueBert512NicuLosAdmissions_2_checkpoint-26015_500_pool/FINALWeightedBlueBert512NicuLosAdmissions_2_checkpoint-26015_500_pool_positive_Fake concept (not present)_.pk
# ['positive_Septicemia', 'positive_Jaundice', 'positive_Other perinatal conditions', 'positive_Suspected Infection', 'positive_Premature birth', 'positive_Patent ductus arteriosus', 'positive_Needs Hepatitis Vaccination', 'positive_Chronic respiratory disease', 'positive_MALE', 'positive_FEMALE', 'positive_Single Birth, Cesarean Section', 'positive_Low birth weight', 'positive_Sleep Apnea', 'positive_Anemia of prematurity', 'positive_Retrolental fibroplasia', 'positive_3+ Birthmates, Cesarian Section', 'positive_Bradycardia', 'positive_Twin Birth, Cesarian Section', 'positive_Respiratory Distress Syndrome', 'positive_Fake concept (not present)', 'positive_Sunday', 'positive_Monday', 'positive_Tuesday', 'positive_Wednesday', 'positive_Thursday', 'positive_Friday', 'positive_Saturday']

# %%
for i, dct in enumerate(NICU_targets):
    NICU_targets[i] = {k:v[:-7] +[np.mean(dct[k][-7:])] for k,v in dct.items()}

# %%
nicu_models= [' '.join(x.split('_')[:2]) for x in nicu_experiment_names]

# %%
import importlib
import plot_utils
importlib.reload(plot_utils)
from plot_utils import *

# %%
order = ['Chronic respiratory disease',
                        'Retrolental fibroplasia',
                        'Septicemia', 
                        'Patent ductus arteriosus', 
                        'Low birth weight', 
                        'Premature birth', 
                        'Anemia of prematurity', 
                        '3+ Birthmates, Cesarian Section', 
                        'Twin Birth, Cesarian Section', 
                        'Bradycardia', 
                        'Sleep Apnea', 
                        'Respiratory Distress Syndrome', 
                        'Jaundice', 
                        'Other perinatal conditions', 
                        'Single Birth, Cesarean Section',
                        'Needs Hepatitis Vaccination', 
                        'Suspected Infection',
                        'FEMALE',
                        'MALE',
                         'Fake concept (not present)',
                        'Day of the Week']

# %%
model_names=['Logistic','MLP','CNN','BERT']
tcav_plot(model_names, NICU_targets, order,nicu_concept_names[:-7]+['Day of the Week'],metric='acc')
# Out:
# <style  type="text/css" >
# #T_9daf2a1e_9348_11ec_9192_70106fb6df5arow0_col0,#T_9daf2a1e_9348_11ec_9192_70106fb6df5arow1_col0,#T_9daf2a1e_9348_11ec_9192_70106fb6df5arow2_col0,#T_9daf2a1e_9348_11ec_9192_70106fb6df5arow3_col0,#T_9daf2a1e_9348_11ec_9192_70106fb6df5arow4_col0,#T_9daf2a1e_9348_11ec_9192_70106fb6df5arow5_col0,#T_9daf2a1e_9348_11ec_9192_70106fb6df5arow6_col0,#T_9daf2a1e_9348_11ec_9192_70106fb6df5arow7_col0,#T_9daf2a1e_9348_11ec_9192_70106fb6df5arow8_col0,#T_9daf2a1e_9348_11ec_9192_70106fb6df5arow9_col0,#T_9daf2a1e_9348_11ec_9192_70106fb6df5arow10_col0,#T_9daf2a1e_9348_11ec_9192_70106fb6df5arow11_col0,#T_9daf2a1e_9348_11ec_9192_70106fb6df5arow12_col0,#T_9daf2a1e_9348_11ec_9192_70106fb6df5arow13_col0,#T_9daf2a1e_9348_11ec_9192_70106fb6df5arow14_col0,#T_9daf2a1e_9348_11ec_9192_70106fb6df5arow15_col0,#T_9daf2a1e_9348_11ec_9192_70106fb6df5arow16_col0,#T_9daf2a1e_9348_11ec_9192_70106fb6df5arow17_col0,#T_9daf2a1e_9348_11ec_9192_70106fb6df5arow18_col0,#T_9daf2a1e_9348_11ec_9192_70106fb6df5arow19_col0,#T_9daf2a1e_9348_11ec_9192_70106fb6df5arow20_col0{
#             max-width:  6px;
#             font-size:  10pt;
#         }#T_9daf2a1e_9348_11ec_9192_70106fb6df5arow0_col1,#T_9daf2a1e_9348_11ec_9192_70106fb6df5arow0_col3,#T_9daf2a1e_9348_11ec_9192_70106fb6df5arow0_col5,#T_9daf2a1e_9348_11ec_9192_70106fb6df5arow0_col7,#T_9daf2a1e_9348_11ec_9192_70106fb6df5arow1_col1,#T_9daf2a1e_9348_11ec_9192_70106fb6df5arow1_col3,#T_9daf2a1e_9348_11ec_9192_70106fb6df5arow1_col5,#T_9daf2a1e_9348_11ec_9192_70106fb6df5arow1_col7,#T_9daf2a1e_9348_11ec_9192_70106fb6df5arow2_col1,#T_9daf2a1e_9348_11ec_9192_70106fb6df5arow2_col3,#T_9daf2a1e_9348_11ec_9192_70106fb6df5arow2_col5,#T_9daf2a1e_9348_11ec_9192_70106fb6df5arow3_col1,#T_9daf2a1e_9348_11ec_9192_70106fb6df5arow3_col3,#T_9daf2a1e_9348_11ec_9192_70106fb6df5arow3_col5,#T_9daf2a1e_9348_11ec_9192_70106fb6df5arow4_col1,#T_9daf2a1e_9348_11ec_9192_70106fb6df5arow4_col3,#T_9daf2a1e_9348_11ec_9192_70106fb6df5arow4_col5,#T_9daf2a1e_9348_11ec_9192_70106fb6df5arow5_col1,#T_9daf2a1e_9348_11ec_9192_70106fb6df5arow5_col3,#T_9daf2a1e_9348_11ec_9192_70106fb6df5arow5_col5,#T_9daf2a1e_9348_11ec_9192_70106fb6df5arow6_col1,#T_9daf2a1e_9348_11ec_9192_70106fb6df5arow6_col3,#T_9daf2a1e_9348_11ec_9192_70106fb6df5arow6_col5,#T_9daf2a1e_9348_11ec_9192_70106fb6df5arow7_col1,#T_9daf2a1e_9348_11ec_9192_70106fb6df5arow7_col3,#T_9daf2a1e_9348_11ec_9192_70106fb6df5arow7_col5,#T_9daf2a1e_9348_11ec_9192_70106fb6df5arow8_col3,#T_9daf2a1e_9348_11ec_9192_70106fb6df5arow8_col5,#T_9daf2a1e_9348_11ec_9192_70106fb6df5arow9_col3,#T_9daf2a1e_9348_11ec_9192_70106fb6df5arow9_col5,#T_9daf2a1e_9348_11ec_9192_70106fb6df5arow10_col1,#T_9daf2a1e_9348_11ec_9192_70106fb6df5arow10_col3,#T_9daf2a1e_9348_11ec_9192_70106fb6df5arow10_col5,#T_9daf2a1e_9348_11ec_9192_70106fb6df5arow11_col3,#T_9daf2a1e_9348_11ec_9192_70106fb6df5arow11_col5,#T_9daf2a1e_9348_11ec_9192_70106fb6df5arow12_col1,#T_9daf2a1e_9348_11ec_9192_70106fb6df5arow12_col3,#T_9daf2a1e_9348_11ec_9192_70106fb6df5arow12_col5,#T_9daf2a1e_9348_11ec_9192_70106fb6df5arow13_col1,#T_9daf2a1e_9348_11ec_9192_70106fb6df5arow13_col3{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 100.0%, transparent 100.0%);
#             max-width:  6px;
#             font-size:  10pt;
#             width:  10em;
#              height:  80%;
#             background:   linear-gradient(90deg, transparent 100.0%, red 100.0%, red 100.0%, transparent 100.0%),linear-gradient(90deg, transparent 0.1%, #5fba7d 0.1%, #5fba7d 100.0%, transparent 100.0%);
#             background-size:  80% 10%, 80% 80% ;
#              background-repeat:  no-repeat, no-repeat;
#              background-position:  0 20%, 0 0 ;
#         }#T_9daf2a1e_9348_11ec_9192_70106fb6df5arow0_col2,#T_9daf2a1e_9348_11ec_9192_70106fb6df5arow6_col2,#T_9daf2a1e_9348_11ec_9192_70106fb6df5arow6_col6{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#26abff 79.0%, transparent 79.0%);
#             max-width:  6px;
#             font-size:  10pt;
#         }#T_9daf2a1e_9348_11ec_9192_70106fb6df5arow0_col4,#T_9daf2a1e_9348_11ec_9192_70106fb6df5arow1_col4,#T_9daf2a1e_9348_11ec_9192_70106fb6df5arow2_col8,#T_9daf2a1e_9348_11ec_9192_70106fb6df5arow9_col4,#T_9daf2a1e_9348_11ec_9192_70106fb6df5arow10_col8{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#26abff 72.0%, transparent 72.0%);
#             max-width:  6px;
#             font-size:  10pt;
#         }#T_9daf2a1e_9348_11ec_9192_70106fb6df5arow0_col6,#T_9daf2a1e_9348_11ec_9192_70106fb6df5arow11_col6{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#26abff 85.0%, transparent 85.0%);
#             max-width:  6px;
#             font-size:  10pt;
#         }#T_9daf2a1e_9348_11ec_9192_70106fb6df5arow0_col8,#T_9daf2a1e_9348_11ec_9192_70106fb6df5arow5_col8,#T_9daf2a1e_9348_11ec_9192_70106fb6df5arow10_col6,#T_9daf2a1e_9348_11ec_9192_70106fb6df5arow12_col8{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#26abff 77.0%, transparent 77.0%);
#             max-width:  6px;
#             font-size:  10pt;
#         }#T_9daf2a1e_9348_11ec_9192_70106fb6df5arow1_col2,#T_9daf2a1e_9348_11ec_9192_70106fb6df5arow4_col4,#T_9daf2a1e_9348_11ec_9192_70106fb6df5arow5_col4{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#26abff 81.0%, transparent 81.0%);
#             max-width:  6px;
#             font-size:  10pt;
#         }#T_9daf2a1e_9348_11ec_9192_70106fb6df5arow1_col6,#T_9daf2a1e_9348_11ec_9192_70106fb6df5arow4_col6,#T_9daf2a1e_9348_11ec_9192_70106fb6df5arow12_col6{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#26abff 86.0%, transparent 86.0%);
#             max-width:  6px;
#             font-size:  10pt;
#         }#T_9daf2a1e_9348_11ec_9192_70106fb6df5arow1_col8,#T_9daf2a1e_9348_11ec_9192_70106fb6df5arow4_col8{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#26abff 76.0%, transparent 76.0%);
#             max-width:  6px;
#             font-size:  10pt;
#         }#T_9daf2a1e_9348_11ec_9192_70106fb6df5arow2_col2,#T_9daf2a1e_9348_11ec_9192_70106fb6df5arow7_col2,#T_9daf2a1e_9348_11ec_9192_70106fb6df5arow10_col2,#T_9daf2a1e_9348_11ec_9192_70106fb6df5arow11_col8{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#26abff 75.0%, transparent 75.0%);
#             max-width:  6px;
#             font-size:  10pt;
#         }#T_9daf2a1e_9348_11ec_9192_70106fb6df5arow2_col4,#T_9daf2a1e_9348_11ec_9192_70106fb6df5arow3_col4,#T_9daf2a1e_9348_11ec_9192_70106fb6df5arow7_col4,#T_9daf2a1e_9348_11ec_9192_70106fb6df5arow17_col6{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#26abff 69.0%, transparent 69.0%);
#             max-width:  6px;
#             font-size:  10pt;
#         }#T_9daf2a1e_9348_11ec_9192_70106fb6df5arow2_col6,#T_9daf2a1e_9348_11ec_9192_70106fb6df5arow9_col8{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#26abff 71.0%, transparent 71.0%);
#             max-width:  6px;
#             font-size:  10pt;
#         }#T_9daf2a1e_9348_11ec_9192_70106fb6df5arow2_col7{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 87.0%, transparent 87.0%);
#             max-width:  6px;
#             font-size:  10pt;
#             width:  10em;
#              height:  80%;
#             background:   linear-gradient(90deg, transparent 53.0%, red 53.0%, red 100.0%, transparent 100.0%),linear-gradient(90deg, transparent 0.1%, #5fba7d 0.1%, #5fba7d 87.0%, transparent 87.0%);
#             background-size:  80% 10%, 80% 80% ;
#              background-repeat:  no-repeat, no-repeat;
#              background-position:  0 20%, 0 0 ;
#         }#T_9
