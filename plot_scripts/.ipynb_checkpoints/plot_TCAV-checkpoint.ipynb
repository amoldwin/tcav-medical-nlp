# %%
import json 
import os
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import math
import pickle
import seaborn as sns
from plot_utils import *

# %%
results_dir = '/data/moldwinar/torch_tcav/tcav_scripts/results'
cavs_dir = '/data/moldwinar/torch_tcav/tcav_scripts/'
nicu_experiment_names = ['logistic_best_steps_84.pt_500_pre_sum',
                         'NICU_MLP_0_checkpoint-28853_500_pool',
                         'CNN_NICU_best_steps_420.pt_500_dropout',
                         'FINALWeightedBlueBert512NicuLosAdmissions_2_checkpoint-26015_500_pool'
                         ]
nicu_concept_names =  ['Septicemia',
                        'Jaundice', 
                        'Other perinatal conditions',
                        'Suspected Infection', 
                        'Premature birth', 
                        'Patent ductus arteriosus',
                        'Needs Hepatitis Vaccination',
                        'Chronic respiratory disease',
                        'MALE', 'FEMALE', 
                        'Single Birth, Cesarean Section', 
                        'Low birth weight', 
                        'Sleep Apnea',                        
                        'Anemia of prematurity', 
                        'Retrolental fibroplasia', 
                        '3+ Birthmates, Cesarian Section', 
                        'Bradycardia', 
                        'Twin Birth, Cesarian Section',
                        'Respiratory Distress Syndrome',
#                        'Fake concept (not present)', 
                        'Sunday','Monday','Tuesday', 'Wednesday', 'Thursday','Friday','Saturday'
                        ]

# %%
NICU_targets = []
for i, exp in enumerate(nicu_experiment_names):
    targets=[exp+'_positive_'+x+'_.pk' for x in nicu_concept_names]
    results = plot_multiple(targets,codes=['positive_'+x for x in nicu_concept_names],scores_dir=os.path.join(results_dir,exp),
                        names=nicu_concept_names,normalized=True,metric='acc',
                        cav_dir=os.path.join(cavs_dir,exp) )
    NICU_targets.append(results)
# Out:
# ['positive_Septicemia', 'positive_Jaundice', 'positive_Other perinatal conditions', 'positive_Suspected Infection', 'positive_Premature birth', 'positive_Patent ductus arteriosus', 'positive_Needs Hepatitis Vaccination', 'positive_Chronic respiratory disease', 'positive_MALE', 'positive_FEMALE', 'positive_Single Birth, Cesarean Section', 'positive_Low birth weight', 'positive_Sleep Apnea', 'positive_Anemia of prematurity', 'positive_Retrolental fibroplasia', 'positive_3+ Birthmates, Cesarian Section', 'positive_Bradycardia', 'positive_Twin Birth, Cesarian Section', 'positive_Respiratory Distress Syndrome', 'positive_Sunday', 'positive_Monday', 'positive_Tuesday', 'positive_Wednesday', 'positive_Thursday', 'positive_Friday', 'positive_Saturday']
# ['positive_Septicemia', 'positive_Jaundice', 'positive_Other perinatal conditions', 'positive_Suspected Infection', 'positive_Premature birth', 'positive_Patent ductus arteriosus', 'positive_Needs Hepatitis Vaccination', 'positive_Chronic respiratory disease', 'positive_MALE', 'positive_FEMALE', 'positive_Single Birth, Cesarean Section', 'positive_Low birth weight', 'positive_Sleep Apnea', 'positive_Anemia of prematurity', 'positive_Retrolental fibroplasia', 'positive_3+ Birthmates, Cesarian Section', 'positive_Bradycardia', 'positive_Twin Birth, Cesarian Section', 'positive_Respiratory Distress Syndrome', 'positive_Sunday', 'positive_Monday', 'positive_Tuesday', 'positive_Wednesday', 'positive_Thursday', 'positive_Friday', 'positive_Saturday']
# ['positive_Septicemia', 'positive_Jaundice', 'positive_Other perinatal conditions', 'positive_Suspected Infection', 'positive_Premature birth', 'positive_Patent ductus arteriosus', 'positive_Needs Hepatitis Vaccination', 'positive_Chronic respiratory disease', 'positive_MALE', 'positive_FEMALE', 'positive_Single Birth, Cesarean Section', 'positive_Low birth weight', 'positive_Sleep Apnea', 'positive_Anemia of prematurity', 'positive_Retrolental fibroplasia', 'positive_3+ Birthmates, Cesarian Section', 'positive_Bradycardia', 'positive_Twin Birth, Cesarian Section', 'positive_Respiratory Distress Syndrome', 'positive_Sunday', 'positive_Monday', 'positive_Tuesday', 'positive_Wednesday', 'positive_Thursday', 'positive_Friday', 'positive_Saturday']
# ['positive_Septicemia', 'positive_Jaundice', 'positive_Other perinatal conditions', 'positive_Suspected Infection', 'positive_Premature birth', 'positive_Patent ductus arteriosus', 'positive_Needs Hepatitis Vaccination', 'positive_Chronic respiratory disease', 'positive_MALE', 'positive_FEMALE', 'positive_Single Birth, Cesarean Section', 'positive_Low birth weight', 'positive_Sleep Apnea', 'positive_Anemia of prematurity', 'positive_Retrolental fibroplasia', 'positive_3+ Birthmates, Cesarian Section', 'positive_Bradycardia', 'positive_Twin Birth, Cesarian Section', 'positive_Respiratory Distress Syndrome', 'positive_Sunday', 'positive_Monday', 'positive_Tuesday', 'positive_Wednesday', 'positive_Thursday', 'positive_Friday', 'positive_Saturday']

# %%
for i, dct in enumerate(NICU_targets):
    NICU_targets[i] = {k:v[:-7] +[np.mean(dct[k][-7:])] for k,v in dct.items()}

# %%
nicu_models= [' '.join(x.split('_')[:2]) for x in nicu_experiment_names]

# %%
import importlib
import plot_utils
importlib.reload(plot_utils)
from plot_utils import *

# %%
order = ['Chronic respiratory disease',
                        'Retrolental fibroplasia',
                        'Septicemia', 
                        'Patent ductus arteriosus', 
                        'Low birth weight', 
                        'Premature birth', 
                        'Anemia of prematurity', 
                        '3+ Birthmates, Cesarian Section', 
                        'Twin Birth, Cesarian Section', 
                        'Bradycardia', 
                        'Sleep Apnea', 
                        'Respiratory Distress Syndrome', 
                        'Jaundice', 
                        'Other perinatal conditions', 
                        'Single Birth, Cesarean Section',
                        'Suspected Infection',
                        'Needs Hepatitis Vaccination', 
                        'FEMALE',
                        'MALE',
                        'Day of the Week']

# %%
nicu_ordered_labels = ['Chronic respiratory disease', 'Retrolental fibroplasia', 'Septicemia', 'Patent ductus arteriosus',
                       'Low birth weight', 'Premature birth', 'Anemia of prematurity', 'Triplets',
                       'Twins', 'Bradycardia', 'Sleep Apnea', 'Respiratory Distress Syndrome', 'Jaundice',
                       'Other perinatal conditions', 'Single Birth', 'Suspected Infection',  'Needs Hepatitis Vaccination',
                     'Female', 'Male', 'Day of the Week']

# %%
nicu_ordered_labels=['$A_{'+str(i+1)+'}$. '+x for i,x in enumerate(nicu_ordered_labels)]

# %%
model_names=['Logistic','MLP','CNN','BERT']
pd.set_option('display.width', 100000)

styled = tcav_plot(model_names, NICU_targets, order,nicu_concept_names[:-7]+['Day of the Week'],metric='acc', ordered_labels = nicu_ordered_labels)

# %%
pd.set_option('display.max_colwidth', 1000)

# %%
styled.columns
# Out:
# MultiIndex([( 'Concept',     ''),
#             ('Logistic', 'TCAV'),
#             ('Logistic',  'acc'),
#             (     'MLP', 'TCAV'),
#             (     'MLP',  'acc'),
#             (     'CNN', 'TCAV'),
#             (     'CNN',  'acc'),
#             (    'BERT', 'TCAV'),
#             (    'BERT',  'acc')],
#            )

# %%
styled.set_properties(subset=['Concept'], **{'width': '250px'})
styled.set_properties(subset=['Concept'], **{'width': '250px'})
# Out:
# <style  type="text/css" >
# #T_cf2be0d8_95a9_11ec_b89f_70106fba9b4erow0_col0,#T_cf2be0d8_95a9_11ec_b89f_70106fba9b4erow1_col0,#T_cf2be0d8_95a9_11ec_b89f_70106fba9b4erow2_col0,#T_cf2be0d8_95a9_11ec_b89f_70106fba9b4erow3_col0,#T_cf2be0d8_95a9_11ec_b89f_70106fba9b4erow4_col0,#T_cf2be0d8_95a9_11ec_b89f_70106fba9b4erow5_col0,#T_cf2be0d8_95a9_11ec_b89f_70106fba9b4erow6_col0,#T_cf2be0d8_95a9_11ec_b89f_70106fba9b4erow7_col0,#T_cf2be0d8_95a9_11ec_b89f_70106fba9b4erow8_col0,#T_cf2be0d8_95a9_11ec_b89f_70106fba9b4erow9_col0,#T_cf2be0d8_95a9_11ec_b89f_70106fba9b4erow10_col0,#T_cf2be0d8_95a9_11ec_b89f_70106fba9b4erow11_col0,#T_cf2be0d8_95a9_11ec_b89f_70106fba9b4erow12_col0,#T_cf2be0d8_95a9_11ec_b89f_70106fba9b4erow13_col0,#T_cf2be0d8_95a9_11ec_b89f_70106fba9b4erow14_col0,#T_cf2be0d8_95a9_11ec_b89f_70106fba9b4erow15_col0,#T_cf2be0d8_95a9_11ec_b89f_70106fba9b4erow16_col0,#T_cf2be0d8_95a9_11ec_b89f_70106fba9b4erow17_col0,#T_cf2be0d8_95a9_11ec_b89f_70106fba9b4erow18_col0,#T_cf2be0d8_95a9_11ec_b89f_70106fba9b4erow19_col0{
#             max-width:  5000px;
#             font-size:  10pt;
#             width:  3000px;
#             width:  9000000px;
#             max-width:  5000px;
#             font-size:  10pt;
#             width:  3000px;
#             width:  9000000px;
#             width:  200px;
#             max-width:  5000px;
#             font-size:  10pt;
#             width:  3000px;
#             width:  9000000px;
#             width:  200px;
#             width:  250px;
#             max-width:  5000px;
#             font-size:  10pt;
#             width:  3000px;
#             width:  9000000px;
#             width:  200px;
#             width:  250px;
#             width:  250px;
#         }#T_cf2be0d8_95a9_11ec_b89f_70106fba9b4erow0_col1,#T_cf2be0d8_95a9_11ec_b89f_70106fba9b4erow0_col3,#T_cf2be0d8_95a9_11ec_b89f_70106fba9b4erow0_col5,#T_cf2be0d8_95a9_11ec_b89f_70106fba9b4erow0_col7,#T_cf2be0d8_95a9_11ec_b89f_70106fba9b4erow1_col1,#T_cf2be0d8_95a9_11ec_b89f_70106fba9b4erow1_col3,#T_cf2be0d8_95a9_11ec_b89f_70106fba9b4erow1_col5,#T_cf2be0d8_95a9_11ec_b89f_70106fba9b4erow1_col7,#T_cf2be0d8_95a9_11ec_b89f_70106fba9b4erow2_col1,#T_cf2be0d8_95a9_11ec_b89f_70106fba9b4erow2_col3,#T_cf2be0d8_95a9_11ec_b89f_70106fba9b4erow2_col5,#T_cf2be0d8_95a9_11ec_b89f_70106fba9b4erow3_col1,#T_cf2be0d8_95a9_11ec_b89f_70106fba9b4erow3_col3,#T_cf2be0d8_95a9_11ec_b89f_70106fba9b4erow3_col5,#T_cf2be0d8_95a9_11ec_b89f_70106fba9b4erow4_col1,#T_cf2be0d8_95a9_11ec_b89f_70106fba9b4erow4_col3,#T_cf2be0d8_95a9_11ec_b89f_70106fba9b4erow4_col5,#T_cf2be0d8_95a9_11ec_b89f_70106fba9b4erow5_col1,#T_cf2be0d8_95a9_11ec_b89f_70106fba9b4erow5_col3,#T_cf2be0d8_95a9_11ec_b89f_70106fba9b4erow5_col5,#T_cf2be0d8_95a9_11ec_b89f_70106fba9b4erow6_col1,#T_cf2be0d8_95a9_11ec_b89f_70106fba9b4erow6_col3,#T_cf2be0d8_95a9_11ec_b89f_70106fba9b4erow6_col5,#T_cf2be0d8_95a9_11ec_b89f_70106fba9b4erow7_col1,#T_cf2be0d8_95a9_11ec_b89f_70106fba9b4erow7_col3,#T_cf2be0d8_95a9_11ec_b89f_70106fba9b4erow7_col5,#T_cf2be0d8_95a9_11ec_b89f_70106fba9b4erow8_col1,#T_cf2be0d8_95a9_11ec_b89f_70106fba9b4erow8_col3,#T_cf2be0d8_95a9_11ec_b89f_70106fba9b4erow8_col5,#T_cf2be0d8_95a9_11ec_b89f_70106fba9b4erow9_col1,#T_cf2be0d8_95a9_11ec_b89f_70106fba9b4erow9_col3,#T_cf2be0d8_95a9_11ec_b89f_70106fba9b4erow9_col5,#T_cf2be0d8_95a9_11ec_b89f_70106fba9b4erow10_col1,#T_cf2be0d8_95a9_11ec_b89f_70106fba9b4erow10_col3,#T_cf2be0d8_95a9_11ec_b89f_70106fba9b4erow10_col5,#T_cf2be0d8_95a9_11ec_b89f_70106fba9b4erow11_col1,#T_cf2be0d8_95a9_11ec_b89f_70106fba9b4erow11_col3,#T_cf2be0d8_95a9_11ec_b89f_70106fba9b4erow11_col5,#T_cf2be0d8_95a9_11ec_b89f_70106fba9b4erow12_col1,#T_cf2be0d8_95a9_11ec_b89f_70106fba9b4erow12_col3,#T_cf2be0d8_95a9_11ec_b89f_70106fba9b4erow12_col5,#T_cf2be0d8_95a9_11ec_b89f_70106fba9b4erow13_col1,#T_cf2be0d8_95a9_11ec_b89f_70106fba9b4erow13_col3{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 100.0%, transparent 100.0%);
#             max-width:  5000px;
#             font-size:  10pt;
#             width:  10em;
#              height:  80%;
#             background:   linear-gradient(90deg, transparent 100.0%, red 100.0%, red 100.0%, transparent 100.0%),linear-gradient(90deg, transparent 0.1%, #5fba7d 0.1%, #5fba7d 100.0%, transparent 100.0%);
#             background-size:  80% 10%, 80% 80% ;
#              background-repeat:  no-repeat, no-repeat;
#              background-position:  0 20%, 0 0 ;
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 100.0%, transparent 100.0%);
#             max-width:  5000px;
#             font-size:  10pt;
#             width:  10em;
#              height:  80%;
#             background:   linear-gradient(90deg, transparent 100.0%, red 100.0%, red 100.0%, transparent 100.0%),linear-gradient(90deg, transparent 0.1%, #5fba7d 0.1%, #5fba7d 100.0%, transparent 100.0%);
#             background-size:  80% 10%, 80% 80% ;
#              background-repeat:  no-repeat, no-repeat;
#              background-position:  0 20%, 0 0 ;
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 100.0%, transparent 100.0%);
#             max-width:  5000px;
#             font-size:  10pt;
#             width:  10em;
#              height:  80%;
#             background:   linear-gradient(90deg, transparent 100.0%, red 100.0%, red 100.0%, transparent 100.0%),linear-gradient(90deg, transparent 0.1%, #5fba7d 0.1%, #5fba7d 100.0%, transparent 100.0%);
#             background-size:  80% 10%, 80% 80% ;
#              background-repeat:  no-repeat, no-repeat;
#              background-position:  0 20%, 0 0 ;
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 100.0%, transparent 100.0%);
#             max-width:  5000px;
#             font-size:  10pt;
#             width:  10em;
#              height:  80%;
#             background:   linear-gradient(90deg, transparent 100.0%, red 100.0%, red 100.0%, transparent 100.0%),linear-gradient(90deg, transparent 0.1%, #5fba7d 0.1%, #5fba7d 100.0%, transparent 100.0%);
#             background-size:  80% 10%, 80% 80% ;
#              background-repeat:  no-repeat, no-repeat;
#              background-position:  0 20%, 0 0 ;
#         }#T_cf2be0d8_95a9_11ec_b89f_70106fba9b4erow0_col2,#T_cf2be0d8_95a9_11ec_b89f_70106fba9b4erow6_col2,#T_cf2be0d8_95a9_11ec_b89f_70106fba9b4erow6_col6{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#26abff 79.0%, transparent 79.0%);
#             max-width:  5000px;
#             font-size:  10pt;
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#26abff 79.0%, transparent 79.0%);
#             max-width:  5000px;
#             font-size:  10pt;
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#26abff 79.0%, transparent 79.0%);
#             max-width:  5000px;
#             font-size:  10pt;
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#26abff 79.0%, transparent 79.0%);
#             max-width:  5000px;
#             font-size:  10pt;
#         }#T_cf2be0d8_95a9_11ec_b89f_70106fba9b4erow0_col4,#T_cf2be0d8_95a9_11ec_b89f_70106fba9b4erow1_col4,#T_cf2be0d8_95a9_11ec_b89f_70106fba9b4erow2_col8,#T_cf2be0d8_95a9_11ec_b89f_70106fba9b4erow9_col4,#T_cf2be0d8_95a9_11ec_b89f_70106fba9b4erow10_col8{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#26abff 72.0%, transparent 72.0%);
#             max-width:  5000px;
#             font-size:  10pt;
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#26abff 72.0%, transparent 72.0%);
#             max-width:  5000px;
#             font-size:  10pt;
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#26abff 72.0%, transparent 72.0%);
#             max-width:  5000px;

# %%
metabolic_experiment_names = ['FINALLogisticCCS_halfsplit_0_best_steps_13.pt_500_pre_sum',
                         'CCS_MLP_TEXT__0_checkpoint-14877_500_pool',
                         'CNN_METABOLIC_best_steps_414.pt_500_dropout',
                         'CCS_BERT_TEXT__0_checkpoint-4959_500_pool',
                              'CCS_just_residual_0_checkpoint-133893_500_finaldense',
                              'CNN_RES_METABOLIC_best_steps_1242.pt_500_final_dense',
                              'checkpoint-13224__500_finaldense'
                         ]
metabolic_concept_names =  ['HYPERTENSION',
                       'HYPERLIPIDEMIA',
                       'MED_ACE',
                       'MED_BETA',
                       'MED_INS', 
                       'MED_FIBR', 
                       'MED_STAT', 
                       'DIABETES',
                       'HYPERGLYCERIDEMIA',
                       'LOWHDL',
                       'OBESE', 
                       'SMOKER', 
                       'YOUNG',
                       'OLD',
                        'Sunday','Monday','Tuesday', 'Wednesday', 'Thursday','Friday','Saturday'
                        ]

# %%
model_names=['Logistic','MLP','CNN','BERT','RMLP\n((structured))','CNN+RMLP\n(str+txt)','BERT+RMLP\n(str+txt)']

# %%
metabolic_targets = []
for i, exp in enumerate(metabolic_experiment_names):
    targets=[exp+'_positive_'+x+'_.pk' for x in metabolic_concept_names]
    results = plot_multiple(targets,codes=['positive_'+x for x in metabolic_concept_names],scores_dir=os.path.join(results_dir,exp),
                        names=metabolic_concept_names,normalized=True,metric='acc',
                        cav_dir=os.path.join(cavs_dir,exp) )
    metabolic_targets.append(results)
# Out:
# ['positive_HYPERTENSION', 'positive_HYPERLIPIDEMIA', 'positive_MED_ACE', 'positive_MED_BETA', 'positive_MED_INS', 'positive_MED_FIBR', 'positive_MED_STAT', 'positive_DIABETES', 'positive_HYPERGLYCERIDEMIA', 'positive_LOWHDL', 'positive_OBESE', 'positive_SMOKER', 'positive_YOUNG', 'positive_OLD', 'positive_Sunday', 'positive_Monday', 'positive_Tuesday', 'positive_Wednesday', 'positive_Thursday', 'positive_Friday', 'positive_Saturday']
# ['positive_HYPERTENSION', 'positive_HYPERLIPIDEMIA', 'positive_MED_ACE', 'positive_MED_BETA', 'positive_MED_INS', 'positive_MED_FIBR', 'positive_MED_STAT', 'positive_DIABETES', 'positive_HYPERGLYCERIDEMIA', 'positive_LOWHDL', 'positive_OBESE', 'positive_SMOKER', 'positive_YOUNG', 'positive_OLD', 'positive_Sunday', 'positive_Monday', 'positive_Tuesday', 'positive_Wednesday', 'positive_Thursday', 'positive_Friday', 'positive_Saturday']
# ['positive_HYPERTENSION', 'positive_HYPERLIPIDEMIA', 'positive_MED_ACE', 'positive_MED_BETA', 'positive_MED_INS', 'positive_MED_FIBR', 'positive_MED_STAT', 'positive_DIABETES', 'positive_HYPERGLYCERIDEMIA', 'positive_LOWHDL', 'positive_OBESE', 'positive_SMOKER', 'positive_YOUNG', 'positive_OLD', 'positive_Sunday', 'positive_Monday', 'positive_Tuesday', 'positive_Wednesday', 'positive_Thursday', 'positive_Friday', 'positive_Saturday']
# ['positive_HYPERTENSION', 'positive_HYPERLIPIDEMIA', 'positive_MED_ACE', 'positive_MED_BETA', 'positive_MED_INS', 'positive_MED_FIBR', 'positive_MED_STAT', 'positive_DIABETES', 'positive_HYPERGLYCERIDEMIA', 'positive_LOWHDL', 'positive_OBESE', 'positive_SMOKER', 'positive_YOUNG', 'positive_OLD', 'positive_Sunday', 'positive_Monday', 'positive_Tuesday', 'positive_Wednesday', 'positive_Thursday', 'positive_Friday', 'positive_Saturday']
# ['positive_HYPERTENSION', 'positive_HYPERLIPIDEMIA', 'positive_MED_ACE', 'positive_MED_BETA', 'positive_MED_INS', 'positive_MED_FIBR', 'positive_MED_STAT', 'positive_DIABETES', 'positive_HYPERGLYCERIDEMIA', 'positive_LOWHDL', 'positive_OBESE', 'positive_SMOKER', 'positive_YOUNG', 'positive_OLD', 'positive_Sunday', 'positive_Monday', 'positive_Tuesday', 'positive_Wednesday', 'positive_Thursday', 'positive_Friday', 'positive_Saturday']
# ['positive_HYPERTENSION', 'positive_HYPERLIPIDEMIA', 'positive_MED_ACE', 'positive_MED_BETA', 'positive_MED_INS', 'positive_MED_FIBR', 'positive_MED_STAT', 'positive_DIABETES', 'positive_HYPERGLYCERIDEMIA', 'positive_LOWHDL', 'positive_OBESE', 'positive_SMOKER', 'positive_YOUNG', 'positive_OLD', 'positive_Sunday', 'positive_Monday', 'positive_Tuesday', 'positive_Wednesday', 'positive_Thursday', 'positive_Friday', 'positive_Saturday']
# ['positive_HYPERTENSION', 'positive_HYPERLIPIDEMIA', 'positive_MED_ACE', 'positive_MED_BETA', 'positive_MED_INS', 'positive_MED_FIBR', 'positive_MED_STAT', 'positive_DIABETES', 'positive_HYPERGLYCERIDEMIA', 'positive_LOWHDL', 'positive_OBESE', 'positive_SMOKER', 'positive_YOUNG', 'positive_OLD', 'positive_Sunday', 'positive_Monday', 'positive_Tuesday', 'positive_Wednesday', 'positive_Thursday', 'positive_Friday', 'positive_Saturday']

# %%
 metabolic_names = ['Hypertension', 'Hyperlipidemia','Ace Inhibitors','Beta Blockers', 'Insulins','Fibrates', 'Statins', 
                       'Diabetes (II)', 'Hyperglyceridemia','Low HDL','Obese','Smoker','Below 65',
                       'Above 65',
                        'Sunday','Monday','Tuesday', 'Wednesday', 'Thursday','Friday','Saturday'
                        ]

# %%
order = metabolic_names[:-7]+['Day of the Week']

# %%
for i, dct in enumerate(metabolic_targets):
    metabolic_targets[i] = {k:v[:-7] +[np.mean(dct[k][-7:])] for k,v in dct.items()}

# %%
tcav_plot(model_names, metabolic_targets, order,order,metric='acc')
# Out:
# <style  type="text/css" >
# #T_dd4e6fd6_941a_11ec_9265_70106fb72684row0_col0,#T_dd4e6fd6_941a_11ec_9265_70106fb72684row1_col0,#T_dd4e6fd6_941a_11ec_9265_70106fb72684row2_col0,#T_dd4e6fd6_941a_11ec_9265_70106fb72684row3_col0,#T_dd4e6fd6_941a_11ec_9265_70106fb72684row4_col0,#T_dd4e6fd6_941a_11ec_9265_70106fb72684row5_col0,#T_dd4e6fd6_941a_11ec_9265_70106fb72684row6_col0,#T_dd4e6fd6_941a_11ec_9265_70106fb72684row7_col0,#T_dd4e6fd6_941a_11ec_9265_70106fb72684row8_col0,#T_dd4e6fd6_941a_11ec_9265_70106fb72684row9_col0,#T_dd4e6fd6_941a_11ec_9265_70106fb72684row10_col0,#T_dd4e6fd6_941a_11ec_9265_70106fb72684row11_col0,#T_dd4e6fd6_941a_11ec_9265_70106fb72684row12_col0,#T_dd4e6fd6_941a_11ec_9265_70106fb72684row13_col0,#T_dd4e6fd6_941a_11ec_9265_70106fb72684row14_col0{
#             max-width:  6px;
#             font-size:  10pt;
#         }#T_dd4e6fd6_941a_11ec_9265_70106fb72684row0_col1,#T_dd4e6fd6_941a_11ec_9265_70106fb72684row3_col5{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 92.0%, transparent 92.0%);
#             max-width:  6px;
#             font-size:  10pt;
#             width:  10em;
#              height:  80%;
#             background:   linear-gradient(90deg, transparent 65.0%, red 65.0%, red 100.0%, transparent 100.0%),linear-gradient(90deg, transparent 0.1%, #5fba7d 0.1%, #5fba7d 92.0%, transparent 92.0%);
#             background-size:  80% 10%, 80% 80% ;
#              background-repeat:  no-repeat, no-repeat;
#              background-position:  0 20%, 0 0 ;
#         }#T_dd4e6fd6_941a_11ec_9265_70106fb72684row0_col2{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#26abff 57.0%, transparent 57.0%);
#             max-width:  6px;
#             font-size:  10pt;
#         }#T_dd4e6fd6_941a_11ec_9265_70106fb72684row0_col3,#T_dd4e6fd6_941a_11ec_9265_70106fb72684row1_col3,#T_dd4e6fd6_941a_11ec_9265_70106fb72684row2_col3,#T_dd4e6fd6_941a_11ec_9265_70106fb72684row3_col9,#T_dd4e6fd6_941a_11ec_9265_70106fb72684row4_col3,#T_dd4e6fd6_941a_11ec_9265_70106fb72684row7_col3,#T_dd4e6fd6_941a_11ec_9265_70106fb72684row10_col7,#T_dd4e6fd6_941a_11ec_9265_70106fb72684row12_col1,#T_dd4e6fd6_941a_11ec_9265_70106fb72684row12_col3,#T_dd4e6fd6_941a_11ec_9265_70106fb72684row13_col3{
#             width:  10em;
#              height:  80%;
#             max-width:  6px;
#             font-size:  10pt;
#             width:  10em;
#              height:  80%;
#         }#T_dd4e6fd6_941a_11ec_9265_70106fb72684row0_col4,#T_dd4e6fd6_941a_11ec_9265_70106fb72684row6_col4{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#26abff 74.0%, transparent 74.0%);
#             max-width:  6px;
#             font-size:  10pt;
#         }#T_dd4e6fd6_941a_11ec_9265_70106fb72684row0_col5,#T_dd4e6fd6_941a_11ec_9265_70106fb72684row0_col7,#T_dd4e6fd6_941a_11ec_9265_70106fb72684row0_col9,#T_dd4e6fd6_941a_11ec_9265_70106fb72684row1_col1,#T_dd4e6fd6_941a_11ec_9265_70106fb72684row1_col5,#T_dd4e6fd6_941a_11ec_9265_70106fb72684row1_col7,#T_dd4e6fd6_941a_11ec_9265_70106fb72684row1_col9,#T_dd4e6fd6_941a_11ec_9265_70106fb72684row1_col13,#T_dd4e6fd6_941a_11ec_9265_70106fb72684row2_col1,#T_dd4e6fd6_941a_11ec_9265_70106fb72684row2_col5,#T_dd4e6fd6_941a_11ec_9265_70106fb72684row2_col7,#T_dd4e6fd6_941a_11ec_9265_70106fb72684row2_col9,#T_dd4e6fd6_941a_11ec_9265_70106fb72684row2_col11,#T_dd4e6fd6_941a_11ec_9265_70106fb72684row3_col11,#T_dd4e6fd6_941a_11ec_9265_70106fb72684row4_col1,#T_dd4e6fd6_941a_11ec_9265_70106fb72684row4_col5,#T_dd4e6fd6_941a_11ec_9265_70106fb72684row4_col7,#T_dd4e6fd6_941a_11ec_9265_70106fb72684row4_col9,#T_dd4e6fd6_941a_11ec_9265_70106fb72684row5_col1,#T_dd4e6fd6_941a_11ec_9265_70106fb72684row5_col3,#T_dd4e6fd6_941a_11ec_9265_70106fb72684row5_col5,#T_dd4e6fd6_941a_11ec_9265_70106fb72684row5_col7,#T_dd4e6fd6_941a_11ec_9265_70106fb72684row5_col9,#T_dd4e6fd6_941a_11ec_9265_70106fb72684row5_col11,#T_dd4e6fd6_941a_11ec_9265_70106fb72684row6_col1,#T_dd4e6fd6_941a_11ec_9265_70106fb72684row6_col5,#T_dd4e6fd6_941a_11ec_9265_70106fb72684row6_col7,#T_dd4e6fd6_941a_11ec_9265_70106fb72684row6_col9,#T_dd4e6fd6_941a_11ec_9265_70106fb72684row7_col1,#T_dd4e6fd6_941a_11ec_9265_70106fb72684row7_col5,#T_dd4e6fd6_941a_11ec_9265_70106fb72684row7_col7,#T_dd4e6fd6_941a_11ec_9265_70106fb72684row7_col9,#T_dd4e6fd6_941a_11ec_9265_70106fb72684row7_col13,#T_dd4e6fd6_941a_11ec_9265_70106fb72684row8_col1,#T_dd4e6fd6_941a_11ec_9265_70106fb72684row8_col3,#T_dd4e6fd6_941a_11ec_9265_70106fb72684row8_col7,#T_dd4e6fd6_941a_11ec_9265_70106fb72684row8_col9,#T_dd4e6fd6_941a_11ec_9265_70106fb72684row9_col1,#T_dd4e6fd6_941a_11ec_9265_70106fb72684row9_col7,#T_dd4e6fd6_941a_11ec_9265_70106fb72684row9_col9,#T_dd4e6fd6_941a_11ec_9265_70106fb72684row10_col1,#T_dd4e6fd6_941a_11ec_9265_70106fb72684row10_col3,#T_dd4e6fd6_941a_11ec_9265_70106fb72684row10_col5,#T_dd4e6fd6_941a_11ec_9265_70106fb72684row10_col9,#T_dd4e6fd6_941a_11ec_9265_70106fb72684row10_col11,#T_dd4e6fd6_941a_11ec_9265_70106fb72684row11_col1,#T_dd4e6fd6_941a_11ec_9265_70106fb72684row11_col7,#T_dd4e6fd6_941a_11ec_9265_70106fb72684row11_col9,#T_dd4e6fd6_941a_11ec_9265_70106fb72684row12_col7,#T_dd4e6fd6_941a_11ec_9265_70106fb72684row13_col1,#T_dd4e6fd6_941a_11ec_9265_70106fb72684row13_col7,#T_dd4e6fd6_941a_11ec_9265_70106fb72684row13_col9,#T_dd4e6fd6_941a_11ec_9265_70106fb72684row14_col7{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 100.0%, transparent 100.0%);
#             max-width:  6px;
#             font-size:  10pt;
#             width:  10em;
#              height:  80%;
#             background:   linear-gradient(90deg, transparent 100.0%, red 100.0%, red 100.0%, transparent 100.0%),linear-gradient(90deg, transparent 0.1%, #5fba7d 0.1%, #5fba7d 100.0%, transparent 100.0%);
#             background-size:  80% 10%, 80% 80% ;
#              background-repeat:  no-repeat, no-repeat;
#              background-position:  0 20%, 0 0 ;
#         }#T_dd4e6fd6_941a_11ec_9265_70106fb72684row0_col6,#T_dd4e6fd6_941a_11ec_9265_70106fb72684row0_col12,#T_dd4e6fd6_941a_11ec_9265_70106fb72684row1_col10,#T_dd4e6fd6_941a_11ec_9265_70106fb72684row8_col10,#T_dd4e6fd6_941a_11ec_9265_70106fb72684row9_col12{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#26abff 92.0%, transparent 92.0%);
#             max-width:  6px;
#             font-size:  10pt;
#         }#T_dd4e6fd6_941a_11ec_9265_70106fb72684row0_col8,#T_dd4e6fd6_941a_11ec_9265_70106fb72684row2_col10,#T_dd4e6fd6_941a_11ec_9265_70106fb72684row4_col6,#T_dd4e6fd6_941a_11ec_9265_70106fb72684row6_col8,#T_dd4e6fd6_941a_11ec_9265_70106fb72684row12_col8,#T_dd4e6fd6_941a_11ec_9265_70106fb72684row13_col8{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#26abff 86.0%, transparent 86.0%);
#             max-width:  6px;
#             font-size:  10pt;
#         }#T_dd4e6fd6_941a_11ec_9265_70106fb72684row0_col10{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#26abff 95.0%, transparent 95.0%);
#             max-width:  6px;
#             font-size:  10pt;
#         }#T_dd4e6fd6_941a_11ec_9265_70106fb72684row0_col11{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 90.0%, transparent 90.0%);
#             max-width:  6px;
#             font-size:  10pt;
#             width:  10em;
#              height:  80%;
#             background:   linear-gradient(90deg, transparent 60.0%, red 60.0%, red 100.0%, transparent 100.0%),linear-gradient(90deg, transparent 0.1%, #5fba7d 0.1%, #5fba7d 90.0%, transparent 90.0%);
#             background-size:  80% 10%, 80% 80% ;
#              background-repeat:  no-repeat, no-repeat;
#              background-position:  0 20%, 0 0 ;
#         }#T_dd4e6fd6_941a_11ec_9265_70106fb72684row0_col13{
#             width:  10em;
#              height:  80%;
#             background:  line
