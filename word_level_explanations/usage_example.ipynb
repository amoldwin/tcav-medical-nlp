# %%
import pickle

from dataset import NewsDataset
from DistilbertModel import DistilBertForSequenceClassification

from smooth_gradient import SmoothGradient
from integrated_gradient import IntegratedGradient

import torch
from torch import nn
from torch.utils.data import DataLoader
from transformers import DistilBertConfig, DistilBertTokenizer
import pandas as pd
from IPython.display import display, HTML
import numpy as np

# %%
config = DistilBertConfig()
config.multi=False
tokenizer = DistilBertTokenizer.from_pretrained("distilbert-base-uncased")
# distilbert = DistilBertForSequenceClassification(config, num_labels=2)

# %%
distilbert = DistilBertForSequenceClassification(config=config)#.from_pretrained(None,config=config,state_dict='distilbert_cad_final1.pt')

# %%
criterion = nn.CrossEntropyLoss()

# %%
batch_size = 1

# %%
path = './distilbert_cad_final1.pt'

if torch.cuda.is_available():
    distilbert.load_state_dict(
        torch.load(path)
    )
else:
    distilbert.load_state_dict(
        torch.load(path, map_location=torch.device('cpu'))
    )
    
# # with open('../label_encoder.sklrn', 'rb') as f:
# #     le = pickle.load(f)

# %%
# distilbert = DistilBertForSequenceClassification.from_pretrained('../tcav/bertcheckpoints/distilbert/distilbert_cad_final1.h5',output_attentions=True, from_tf=True)

# %%
# np.array([[0]*512]).size()

# %%
# predictions=distilbert(input_ids=torch.tensor([[0]*512]),return_dict=True,output_hidden_states=True)

# %%
# vars(predictions)

# %%
test_df = pd.read_csv('../tcav2/data/CAD_test.csv')

# %%
texts = list(test_df['TEXT'])

# %%
all_instances = []
texts=['Patient was a pleasant male in his early 40s who was given plavix and aspirin for CAD and required cabg. Neonatology Attending Note\n\nID/CC: Infant is a [**2095**] gm, 35 [**4-23**] week, male triplet (C), who was admitted to the NICU for further management of prematurity, hypoglycemia, and temperature instability.\n\nHPI:\nMother is a 32 y.o. G3P0 woman. Prior obstetrical history notable for two prior losses in [**2141**]- 6 week [**Doctor Last Name 3663**] and 8 week IUI triplets. This pregnancy also IUI conceived. Pregnancy relatively uncomplicated. Admitted at 31 3/7 weeks for preterm labor. Received magnesium and betamethasone complete. Later discharged home. Fetal growth has been followed closely. All have been slightly small. However, due to growth concerns in triplet A, decided to deliver today.\n\nMeds: PNV, baby ASA due to prior losses.\n\nSocial: Mother an occupational therapist at [**Name (NI) 1402**] NICU.\n\nInfant delivered by Cesarean section. Apgars 8,9. Initially observed in L&D, however, due to low dextrostick and temperature instability, infant admitted to NICU for further management.\n\nExam:\nVS per CareView.\nGrowth parameters: Wt [**2095**] g = 10-25%; L 42 cm = 10%; HC 31.5 cm = 25%.\nPE recorded in "Newborm Examination Form".  No abnormalities.\n\nImpression:\nPremature male triplet (C)\nHypoglycemia\nTemperature instability\nGrowth better than siblings, but still only around 10-25%.\n\nPlan:\nWill continue to monitor glucose levels and temperature stability. Both likely due to prematurity and marginal fetal growth. Currently without cardiac or respiratory issues. Will follow for the development of apnea of prematurity. Will allow to p.o. feed ad lib as tolerated.\n\nParents updated.\n\nPedi: E. [**Doctor Last Name 3664**], [**Location (un) 597**].', 'Patient is healthy']
for text in texts:
    test_example = [
        [text], 
        [""]
    ]

    test_dataset = NewsDataset(
        data_list=test_example,
        tokenizer=tokenizer,
        max_length=config.max_position_embeddings, 
    )

    test_dataloader = DataLoader(
        test_dataset,
        batch_size=batch_size,
        shuffle=False,
    )

    integrated_grad = IntegratedGradient(
        distilbert, 
        criterion, 
        tokenizer, 
        show_progress=True,
        encoder="bert"
    )
    instances = integrated_grad.saliency_interpret(test_dataloader)
    all_instances.append(instances)
# Out:
# 100%|██████████| 1/1 [00:02<00:00,  2.13s/it]
# 100%|██████████| 1/1 [00:01<00:00,  1.97s/it]

# %%
all_instances
# Out:
# [[{'tokens': ['[CLS]',
#     'patient',
#     'was',
#     'a',
#     'pleasant',
#     'male',
#     'in',
#     'his',
#     'early',
#     '40',
#     '##s',
#     'who',
#     'was',
#     'given',
#     'pl',
#     '##avi',
#     '##x',
#     'and',
#     'as',
#     '##pi',
#     '##rin',
#     'for',
#     'cad',
#     'and',
#     'required',
#     'cab',
#     '##g',
#     '.',
#     'neon',
#     '##ato',
#     '##logy',
#     'attending',
#     'note',
#     'id',
#     '/',
#     'cc',
#     ':',
#     'infant',
#     'is',
#     'a',
#     '[',
#     '*',
#     '*',
#     '209',
#     '##5',
#     '*',
#     '*',
#     ']',
#     'gm',
#     ',',
#     '35',
#     '[',
#     '*',
#     '*',
#     '4',
#     '-',
#     '23',
#     '*',
#     '*',
#     ']',
#     'week',
#     ',',
#     'male',
#     'triple',
#     '##t',
#     '(',
#     'c',
#     ')',
#     ',',
#     'who',
#     'was',
#     'admitted',
#     'to',
#     'the',
#     'nic',
#     '##u',
#     'for',
#     'further',
#     'management',
#     'of',
#     'prem',
#     '##at',
#     '##urity',
#     ',',
#     'h',
#     '##yp',
#     '##og',
#     '##ly',
#     '##ce',
#     '##mia',
#     ',',
#     'and',
#     'temperature',
#     'instability',
#     '.',
#     'hp',
#     '##i',
#     ':',
#     'mother',
#     'is',
#     'a',
#     '32',
#     'y',
#     '.',
#     'o',
#     '.',
#     'g',
#     '##3',
#     '##p',
#     '##0',
#     'woman',
#     '.',
#     'prior',
#     'ob',
#     '##ste',
#     '##tric',
#     '##al',
#     'history',
#     'notable',
#     'for',
#     'two',
#     'prior',
#     'losses',
#     'in',
#     '[',
#     '*',
#     '*',
#     '214',
#     '##1',
#     '*',
#     '*',
#     ']',
#     '-',
#     '6',
#     'week',
#     '[',
#     '*',
#     '*',
#     'doctor',
#     'last',
#     'name',
#     '36',
#     '##6',
#     '##3',
#     '*',
#     '*',
#     ']',
#     'and',
#     '8',
#     'week',
#     'i',
#     '##ui',
#     'triple',
#     '##ts',
#     '.',
#     'this',
#     'pregnancy',
#     'also',
#     'i',
#     '##ui',
#     'conceived',
#     '.',
#     'pregnancy',
#     'relatively',
#     'un',
#     '##com',
#     '##pl',
#     '##icated',
#     '.',
#     'admitted',
#     'at',
#     '31',
#     '3',
#     '/',
#     '7',
#     'weeks',
#     'for',
#     'pre',
#     '##ter',
#     '##m',
#     'labor',
#     '.',
#     'received',
#     'magnesium',
#     'and',
#     'beta',
#     '##met',
#     '##has',
#     '##one',
#     'complete',
#     '.',
#     'later',
#     'discharged',
#     'home',
#     '.',
#     'fetal',
#     'growth',
#     'has',
#     'been',
#     'followed',
#     'closely',
#     '.',
#     'all',
#     'have',
#     'been',
#     'slightly',
#     'small',
#     '.',
#     'however',
#     ',',
#     'due',
#     'to',
#     'growth',
#     'concerns',
#     'in',
#     'triple',
#     '##t',
#     'a',
#     ',',
#     'decided',
#     'to',
#     'deliver',
#     'today',
#     '.',
#     'med',
#     '##s',
#     ':',
#     'p',
#     '##n',
#     '##v',
#     ',',
#     'baby',
#     'asa',
#     'due',
#     'to',
#     'prior',
#     'losses',
#     '.',
#     'social',
#     ':',
#     'mother',
#     'an',
#     'occupational',
#     'therapist',
#     'at',
#     '[',
#     '*',
#     '*',
#     'name',
#     '(',
#     'ni',
#     ')',
#     '140',
#     '##2',
#     '*',
#     '*',
#     ']',
#     'nic',
#     '##u',
#     '.',
#     'infant',
#     'delivered',
#     'by',
#     'cesare',
#     '##an',
#     'section',
#     '.',
#     'ap',
#     '##gar',
#     '##s',
#     '8',
#     ',',
#     '9',
#     '.',
#     'initially',
#     'observed',
#     'in',
#     'l',
#     '&',
#     'd',
#     ',',
#     'however',
#     ',',
#     'due',
#     'to',
#     'low',
#     'dex',
#     '##tro',
#     '##stick',
#     'and',
#     'temperature',
#     'instability',
#     ',',
#     'infant',
#     'admitted',
#     'to',
#     'nic',
#     '##u',
#     'for',
#     'further',
#     'management',
#     '.',
#     'exam',
#     ':',
#     'vs',
#     'per',
#     'care',
#     '##view',
#     '.',
#     'growth',
#     'parameters',
#     ':',
#     'w',
#     '##t',
#     '[',
#     '*',
#     '*',
#     '209',
#     '##5',
#     '*',
#     '*',
#     ']',
#     'g',
#     '=',
#     '10',
#     '-',
#     '25',
#     '%',
#     ';',
#     'l',
#     '42',
#     'cm',
#     '=',
#     '10',
#     '%',
#     ';',
#     'hc',
#     '31',
#     '.',
#     '5',
#     'cm',
#     '=',
#     '25',
#     '%',
#     '.',
#     'pe',
#     'recorded',
#     'in',
#     '"',
#     'new',
#     '##bor',
#     '##m',
#     'examination',
#     'form',
#     '"',
#     '.',
#     'no',
#     'abnormalities',
#     '.',
#     'impression',
#     ':',
#     'premature',
#     'male',
#     'triple',
#     '##t',
#     '(',
#     'c',
#     ')',
#     'h',
#     '##yp',
#     '##og',
#     '##ly',
#     '##ce',
#     '##mia',
#     'temperature',
#     'instability',
#     'growth',
#     'better',
#     'than',
#     'siblings',
#     ',',
#     'but',
#     'still',
#     'only',
#     'around',
#     '10',
#     '-',
#     '25',
#     '%',
#     '.',
#     'plan',
#     ':',
#     'will',
#     'continue',
#     'to',
#     'monitor',
#     'glucose',
#     'levels',
#     'and',
#     'temperature',
#     'stability',
#     '.',
#     'both',
#     'likely',
#     'due',
#     'to',
#     'prem',
#     '##at',
#     '##urity',
#     'and',
#     'marginal',
#     'fetal',
#     'growth',
#     '.',
#     'currently',
#     'without',
#     'cardiac',
#     'or',
#     'respiratory',
#     'issues',
#     '.',
#     'will',
#     'follow',
#     'for',
#     'the',
#     'development',
#     'of',
#     'ap',
#     '##nea',
#     'of',
#     'prem',
#     '##at',
#     '##urity',
#     '.',
#     'will',
#     'allow',
#     'to',
#     'p',
#     '.',
#     'o',
#     '.',
#     'feed',
#     'ad',
#     'li',
#     '##b',
#     'as',
#     'tolerated',
#     '.',
#     'parents',
#     'updated',
#     '.',
#     'pe',
#     '##di',
#     ':',
#     'e',
#     '.',
#     '[',
#     '*',
#     '*',
#     'doctor',
#     'last',
#     'name',
#     '36',
#     '##64',
#     '*',
#     '*',
#     ']',
#     ',',
#     '[',
#     '*',
#     '*',
#     'location',
#     '(',
#     'un',
#     ')',
#     '59',
#     '##7',
#     '*',
#     '*',
#     ']',
#     '.',
#     '[SEP]'],
#    'grad': [0.0022049760445952415,
#     0.0004449562984518707,
#     0.00322613469325006,
#     0.005748725030571222,
#     0.007787446491420269,
#     0.009929869323968887,
#     0.0011556401150301099,
#     0.0077946241945028305,
#     0.003159866202622652,
#     0.0013290171045809984,
#     0.0009302734397351742,
#     0.0005966546013951302,
#     0.0034237524960190058,
#     0.000718449882697314,
#     0.003139353822916746,
#     0.01474721822887659,
#     0.012030526995658875,
#     0.003106537973508239,
#     0.0005648345104418695,
#     0.004221191629767418,
#     0.0044930195435881615,
#     0.004403837490826845,
#     0.018707262352108955,
#     0.003305494086816907,
#     0.006598571315407753,
#     0.12219777703285217,
#     0.073091059923172,
#     0.03445475548505783,
#     0.0007190601900219917,
#     0.0024322376120835543,
#     0.00725600216537714,
#     0.0020192221272736788,
#     0.0034913313575088978,
#     0.0020742949564009905,
#     0.002946942113339901,
#     0.0038145752623677254,
#     0.0019177139038220048,
#     0.00036029424518346786,
#     0.000779004127252847,
#     0.001307843835093081,
#     0.0014053764753043652,
#     0.0005164229078218341,
#     0.000617406505625695,
#     0.0006548973033204675,
#     0.0010807501384988427,
#     0.0008012079633772373,
#     0.0006058181170374155,
#     0.0027817494701594114,
#     0.004204686265438795,
#     0.00210023601539433,
#     0.003163508605211973,
#     0.0009049182408489287,
#     0.002075392520055175,
#     0.0003564298094715923,
#     0.0018350806785747409,
#     0.00012236744805704802,
#     0.002248460426926613,
#     0.0012486778432503343,
#     0.001599193550646305,
#     0.0007769127259962261,
#     0.00154207949526608,
#     0.0007782494067214429,
#     0.0024660583585500717,
#     0.0004456954775378108,
#     0.0009638259070925415,
#     0.0002129550266545266,
#     0.0007358266157098114,
#     0.0002467183512635529,
#     0.0004298053390812129,
#     0.0011112147476524115,
#     0.001314977533183992,
#     0.0008560984279029071,
#     0.0005146576440893114,
#     0.010674732737243176,
#     0.00866150576621294,
#     0.0200324859470129,
#     0.0029354365542531013,
#     0.0004604972491506487,
#     0.0026475409977138042,
#     0.00015165169315878302,
#     6.679011858068407e-05,
#     0.0023936117067933083,
#     0.002892828779295087,
#     0.0016279933042824268,
#     0.00039954192470759153,
#     0.0005235638818703592,
#     0.0028599435463547707,
#     0.002316788537427783,
#     0.0036770724691450596,
#     0.0010343596804887056,
#     0.00045898641110397875,
#     0.0005347041878849268,
#     0.00028860403108410537,
#     0.0017149322666227818,
#     0.0016425733920186758,
#     0.0023233341053128242,
#     0.001118444954045117,
#     0.0012875921092927456,
#     0.002510828198865056,
#     0.0006415004609152675,
#     0.0005391685990616679,
#     0.0003655187611002475,
#     0.0008539902628399432,
#     0.0007066984544508159,
#     0.0014877775683999062,
#     0.0003107665979769081,
#     0.0003693800244946033,
#     0.0014817605260759592,
#     0.0007341786986216903,
#     3.5171349736629054e-05,
#     0.0006195624591782689,
#     0.001224167994223535,
#     0.0007127979188226163,
#     0.0005844614934176207,
#     0.0005271759000606835,
#     0.0005497836391441524,
#     0.0005550744826905429,
#     0.0004476634494494647,
#     0.00032310112146660686,
#     0.0014999370323494077,
#     0.0007214220822788775,
#     0.0010717797558754683,
#     3.789914262597449e-05,
#     2.785003925964702e-05,
#     0.0028227369766682386,
#     0.0009329108288511634,
#     0.0009752820478752255,
#     0.0023158665280789137,
#     0.002984643215313554,
#     0.18410976231098175],
#    'label': 1,
#    'prob': 0.8979554176330566}],
#  [{'tokens': ['[CLS]', 'patient', 'is', 'healthy', '[SEP]'],
#    'grad': [0.11000867187976837,
#     0.10540944337844849,
#     0.01492229476571083,
#     0.03863537684082985,
#     0.7310242056846619],
#    'label': 1,
#    'prob': 0.5720639228820801}]]

# %%
coloder_string = integrated_grad.colorize(instances[0])
display(HTML(coloder_string))
# Out:
# Using bos_token, but it is not set yet.
# <span class="barcode"; style="color: black; background-color: #ddeaf7"> [CLS]</span><span class="barcode"; style="color: black; background-color: #deebf7"> patient</span><span class="barcode"; style="color: black; background-color: #f7fbff"> is</span><span class="barcode"; style="color: black; background-color: #f1f7fd"> healthy</span><span class="barcode"; style="color: black; background-color: #08306b"> [SEP]</span><span class="barcode"; style="color: black; background-color: 0">    Label: 1 |</span><span class="barcode"; style="color: black; background-color: #56b567">57.21%</span>|

# %%
grads_df = pd.DataFrame([instance[0] for instance in all_instances])#.to_csv('all_test_grads.csv')

# %%
def unravel(lst):
    return [i for j in lst for i in j]

# %%
import pandas as pd

# grads_df = pd.read_csv('all_test_grads2.csv')
grads_df = pd.read_csv('all_train_grads2.csv')

# %%
grads_df['tokens']=grads_df['tokens'].apply(eval)

# %%
grads_df['grad'] = grads_df['grad'].apply(eval)

# %%
ex = grads_df.sort_values(by='prob',ascending=False).iloc[3]
coloder_string=integrated_grad.colorize({'tokens':ex['tokens'], 'grad':ex['grad'], 'label':ex['label'],'prob':ex['prob']})
display(HTML(coloder_string))
# Out:
# <span class="barcode"; style="color: black; background-color: #b3d3e8"> [CLS]</span><span class="barcode"; style="color: black; background-color: #c8dcf0"> corona</span><span class="barcode"; style="color: black; background-color: #e0ecf8">ry</span><span class="barcode"; style="color: black; background-color: #084285"> artery</span><span class="barcode"; style="color: black; background-color: #b2d2e8"> bypass</span><span class="barcode"; style="color: black; background-color: #95c5df"> graf</span><span class="barcode"; style="color: black; background-color: #f2f7fd">t</span><span class="barcode"; style="color: black; background-color: #c9ddf0"> (</span><span class="barcode"; style="color: black; background-color: #0d57a1"> cab</span><span class="barcode"; style="color: black; background-color: #2f7fbc">g</span><span class="barcode"; style="color: black; background-color: #cadef0"> )</span><span class="barcode"; style="color: black; background-color: #e7f0fa"> assessment</span><span class="barcode"; style="color: black; background-color: #f5fafe"> :</span><span class="barcode"; style="color: black; background-color: #f3f8fe"> oriented</span><span class="barcode"; style="color: black; background-color: #f5f9fe"> x</span><span class="barcode"; style="color: black; background-color: #f6faff">3</span><span class="barcode"; style="color: black; background-color: #f5f9fe"> .</span><span class="barcode"; style="color: black; background-color: #f2f7fd"> c</span><span class="barcode"; style="color: black; background-color: #f3f8fe"> /</span><span class="barcode"; style="color: black; background-color: #f6faff"> o</span><span class="barcode"; style="color: black; background-color: #f6faff"> inc</span><span class="barcode"; style="color: black; background-color: #f3f8fe">ision</span><span class="barcode"; style="color: black; background-color: #f7fbff">al</span><span class="barcode"; style="color: black; background-color: #eff6fc"> pain</span><span class="barcode"; style="color: black; background-color: #f4f9fe"> 5</span><span class="barcode"; style="color: black; background-color: #f5fafe"> out</span><span class="barcode"; style="color: black; background-color: #f6faff"> of</span><span class="barcode"; style="color: black; background-color: #f6faff"> 10</span><span class="barcode"; style="color: black; background-color: #f6faff"> .</span><span class="barcode"; style="color: black; background-color: #eff6fc"> ns</span><span class="barcode"; style="color: black; background-color: #f2f8fd">r</span><span class="barcode"; style="color: black; background-color: #f7fbff"> .</span><span class="barcode"; style="color: black; background-color: #f6faff"> no</span><span class="barcode"; style="color: black; background-color: #f7fbff"> ve</span><span class="barcode"; style="color: black; background-color: #f5f9fe">a</span><span class="barcode"; style="color: black; background-color: #f7fbff"> .</span><span class="barcode"; style="color: black; background-color: #f5fafe"> h</span><span class="barcode"; style="color: black; background-color: #f5fafe">yp</span><span class="barcode"; style="color: black; background-color: #f7fbff">ote</span><span class="barcode"; style="color: black; background-color: #f7fbff">ns</span><span class="barcode"; style="color: black; background-color: #f7fbff">ive</span><span class="barcode"; style="color: black; background-color: #f6faff"> sb</span><span class="barcode"; style="color: black; background-color: #f7fbff">p</span><span class="barcode"; style="color: black; background-color: #f5fafe"> 80</span><span class="barcode"; style="color: black; background-color: #f5fafe"> s</span><span class="barcode"; style="color: black; background-color: #f2f8fd"> .</span><span class="barcode"; style="color: black; background-color: #eff6fc"> ci</span><span class="barcode"; style="color: black; background-color: #f7fbff"> /</span><span class="barcode"; style="color: black; background-color: #f0f6fd"> co</span><span class="barcode"; st ...

# %%
all_positive_grads = pd.DataFrame(  list(zip( unravel(grads_df[grads_df['label']==1]['tokens']),  unravel(grads_df[grads_df['label']==1]['grad']) )) , columns=['tokens', 'grad']  )

# %%
all_negative_grads = pd.DataFrame(  list(zip( unravel(grads_df[grads_df['label']==0]['tokens']),  unravel(grads_df[grads_df['label']==0]['grad']) )) , columns=['tokens', 'grad']  )

# %%
# all_negative_grads

# %%
word =''
score=0
words=[]
scores=[]
for i in reversed(range(len(all_positive_grads))):
    token=all_positive_grads['tokens'].iloc[i]
    if token.startswith('##'):
        word = token[2:]+word
        score = max(score,all_positive_grads['grad'].iloc[i] )
#         print(word)
    else:
        word = token+word
#         print(word)
        words.append(word)
        score = max(score,all_positive_grads['grad'].iloc[i] )
        scores.append(score)
        word=''
        score=0

# %%
tokens_grouped = pd.DataFrame(list(zip(words, scores)), columns=['words', 'grad']).groupby('words')
means = tokens_grouped['grad'].mean()
cts = tokens_grouped['grad'].count()
wrds = tokens_grouped.apply(lambda group: str(group.name))
positive_df = pd.DataFrame(list(zip(wrds,means,cts)), columns=['word','grad_mean','word_count' ]).sort_values(by='grad_mean',ascending=False)
positive_df = positive_df[positive_df['word_count']>5]
print(positive_df.head(25).to_latex(index=False, float_format="%.3f"))
# Out:
# \begin{tabular}{lrr}
# \toprule
#            word &  grad\_mean &  word\_count \\
# \midrule
#          cabgx1 &      0.127 &          14 \\
#          cabgx3 &      0.110 &          45 \\
#          cabgx5 &      0.107 &           7 \\
#          cabgx4 &      0.094 &          41 \\
#          cabgx2 &      0.086 &          21 \\
#            cabg &      0.083 &        2210 \\
#           [SEP] &      0.067 &        9364 \\
#             cad &      0.063 &        1344 \\
#  bronchodilator &      0.054 &           6 \\
#             rca &      0.052 &         655 \\
#          artery &      0.039 &         703 \\
#      integrelin &      0.035 &         105 \\
#            simv &      0.034 &         351 \\
#      fasciotomy &      0.033 &           6 \\
#           wires &      0.030 &        1200 \\
#            pvcs &      0.029 &         310 \\
#             lad &      0.028 &         981 \\
#     thoracotomy &      0.028 &          31 \\
#             ace &      0.027 &         365 \\
#         insulin &      0.027 &        2962 \\
#             pvc &      0.027 &        1071 \\
#           pmicu &      0.027 &          23 \\
#         nailbed &      0.027 &           6 \\
#       maneuvers &      0.026 &           6 \\
#             lbp &      0.026 &           6 \\
# \bottomrule
# \end{tabular}

# %%
word =''
score=0
negative_words=[]
negative_scores=[]
for i in reversed(range(len(all_negative_grads))):
    token=all_negative_grads['tokens'].iloc[i]
    if token.startswith('##'):
        word = token[2:]+word
        score = max(score,all_negative_grads['grad'].iloc[i] )
#         print(word)
    else:
        word = token+word
#         print(word)
        negative_words.append(word)
        score = max(score,all_negative_grads['grad'].iloc[i] )
        negative_scores.append(score)
        word=''
        score=0

# %%
tokens_grouped = pd.DataFrame(list(zip(negative_words, negative_scores)), columns=['words', 'grad']).groupby('words')
means = tokens_grouped['grad'].mean()
cts = tokens_grouped['grad'].count()
wrds = tokens_grouped.apply(lambda group: str(group.name))
negative_df = pd.DataFrame(list(zip(wrds,means,cts)), columns=['word','grad_mean','word_count' ]).sort_values(by='grad_mean',ascending=False)
negative_df = negative_df[negative_df['word_count']>5]
print(negative_df.head(25).to_latex(index=False, float_format="%.3f"))
# Out:
# \begin{tabular}{lrr}
# \toprule
#                 word &  grad\_mean &  word\_count \\
# \midrule
#                  cad &      0.094 &          76 \\
#                [SEP] &      0.081 &        6819 \\
#                  lad &      0.075 &           7 \\
#            narrative &      0.069 &          37 \\
#                 cabg &      0.068 &          10 \\
#                  npn &      0.064 &         762 \\
#            cadaveric &      0.057 &           7 \\
#                  pvc &      0.047 &         480 \\
#                 pvcs &      0.042 &         166 \\
#                  ccu &      0.040 &         306 \\
#                 simv &      0.037 &          72 \\
#          prostectomy &      0.036 &           6 \\
#          thorocotomy &      0.036 &           6 \\
#               pedial &      0.035 &          20 \\
#                tsicu &      0.035 &         516 \\
#    gastrojejunostomy &      0.033 &           7 \\
#            lobectomy &      0.032 &          65 \\
#                 sicu &      0.032 &        1475 \\
#  esophagogastrectomy &      0.032 &          19 \\
#                  pvd &      0.032 &          78 \\
#                 csru &      0.031 &          58 \\
#                msicu &      0.030 &          16 \\
#                 cart &      0.030 &          11 \\
#         thrombectomy &      0.029 &          16 \\
#         annuloplasty &      0.029 &           9 \\
# \bottomrule
# \end{tabular}

# %%
list(means
# Out:
# ['grad']

# %%
pd.DataFrame(list(zip(words, scores)), columns=['words', 'grad'])
# Out:
#        words      grad
# 0          '  0.028707
# 1          a  0.051793
# 2          i  0.001401
# 3          s  0.000330
# 4          e  0.005617
# ...      ...       ...
# 117397     L  0.007958
# 117398     C  0.003365
# 117399     [  0.001415
# 117400     '  0.005063
# 117401     [  0.007274
#
# [117402 rows x 2 columns]

# %%
import pandas as pd
pd.DataFrame(list(zip(instances[0]['tokens'], instances[0]['grad'])))
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-57-d62e443bf3c7> in <module>
#       1 import pandas as pd
# ----> 2 pd.DataFrame(list(zip(instances[1]['tokens'], instances[1]['grad'])))
#
# IndexError: list index out of range

# %%
instances
# Out:
# [{'tokens': ['[CLS]',
#    "'",
#    'patient',
#    'was',
#    'a',
#    'pleasant',
#    'male',
#    'in',
#    'his',
#    'early',
#    '40',
#    '##s',
#    'who',
#    'was',
#    'given',
#    'pl',
#    '##avi',
#    '##x',
#    'and',
#    'as',
#    '##pi',
#    '##rin',
#    'for',
#    'cad',
#    'and',
#    'required',
#    'cab',
#    '##g',
#    "'",
#    '[SEP]',
#    'transform',
#    '##er',
#    '-',
#    'based',
#    'models',
#    'have',
#    'taken',
#    'a',
#    'leading',
#    'role',
#    'in',
#    'nl',
#    '##p',
#    'today',
#    '.',
#    '[SEP]'],
#   'grad': [0.0024040760472416878,
#    0.011202486231923103,
#    0.013759119436144829,
#    0.002332319738343358,
#    0.011373970657587051,
#    0.02735648676753044,
#    0.015535157173871994,
#    0.030777039006352425,
#    0.008332711644470692,
#    0.013340604491531849,
#    0.0001066805562004447,
#    0.0027349493466317654,
#    0.004292184952646494,
#    0.00442542415112257,
#    0.007150531280785799,
#    0.0028611449524760246,
#    0.015010221861302853,
#    0.018782952800393105,
#    0.01669878326356411,
#    0.009789077565073967,
#    0.016139263287186623,
#    0.007285908330231905,
#    0.0340462364256382,
#    0.0994633287191391,
#    0.02390855737030506,
#    0.01794828474521637,
#    0.17008531093597412,
#    0.12981343269348145,
#    0.021933887153863907,
#    0.1389886736869812,
#    0.020783530548214912,
#    0.0065027992241084576,
#    0.008362825959920883,
#    0.0033463663421571255,
#    0.003560791490599513,
#    0.0011002038372680545,
#    0.00035022245720028877,
#    0.020194558426737785,
#    0.002988012507557869,
#    0.0009293951443396509,
#    0.0005665147327817976,
#    0.004190972540527582,
#    0.004393792245537043,
#    0.003207903355360031,
#    0.003286235500127077,
#    0.03835707902908325],
#   'label': 1,
#   'prob': 0.985454797744751}]
